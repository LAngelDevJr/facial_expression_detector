# %%
import os
import cv2
from tqdm import tqdm

# Ruta base donde se encuentran los datos
base_path = r'C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO 2\senas_procesadas'

def find_generated_videos():
    """
    Busca todos los videos MP4 en las carpetas de muestras
    
    Returns:
        list: Lista de tuplas (expresión, muestra, nombre_video, ruta_completa)
    """
    videos_found = []
    
    # Recorrer todas las carpetas de expresiones
    for expression in os.listdir(base_path):
        expression_path = os.path.join(base_path, expression)
        
        if not os.path.isdir(expression_path):
            continue
            
        # Recorrer las carpetas de muestras
        try:
            for muestra_folder in os.listdir(expression_path):
                muestra_path = os.path.join(expression_path, muestra_folder)
                
                if not os.path.isdir(muestra_path) or not muestra_folder.startswith('muestra_'):
                    continue
                    
                # Buscar archivos MP4 en la carpeta de muestra
                for file in os.listdir(muestra_path):
                    if file.endswith('.mp4'):
                        video_path = os.path.join(muestra_path, file)
                        videos_found.append((expression, muestra_folder, file, video_path))
        except Exception as e:
            print(f"Error al explorar {expression_path}: {e}")
    
    return videos_found

def display_videos(videos):
    """
    Muestra la lista de videos encontrados con detalles
    
    Args:
        videos: Lista de tuplas (expresión, muestra, nombre_video, ruta_completa)
    """
    if not videos:
        print("❌ No se encontraron videos generados.")
        return
    
    print(f"📊 Videos encontrados ({len(videos)}):\n")
    
    for i, (expression, muestra, video, video_path) in enumerate(videos, 1):
        video_size_mb = os.path.getsize(video_path) / (1024 * 1024)
        
        # Obtener información del video usando OpenCV
        cap = cv2.VideoCapture(video_path)
        if not cap.isOpened():
            print(f"{i}. {expression}/{muestra}/{video} - ⚠️ No se pudo abrir el video")
            continue
            
        # Obtener propiedades
        fps = cap.get(cv2.CAP_PROP_FPS)
        frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
        width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
        height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
        duration = frame_count / fps if fps > 0 else 0
        
        cap.release()
        
        print(f"{i}. {expression}/{muestra}/{video}")
        print(f"   - Tamaño: {video_size_mb:.2f} MB")
        print(f"   - Resolución: {width}x{height}")
        print(f"   - FPS: {fps:.2f}")
        print(f"   - Frames: {frame_count}")
        print(f"   - Duración: {duration:.2f} segundos\n")

def delete_all_videos(videos):
    """
    Elimina todos los videos de la lista
    
    Args:
        videos: Lista de tuplas (expresión, muestra, nombre_video, ruta_completa)
    
    Returns:
        int: Número de videos eliminados
    """
    if not videos:
        print("❌ No hay videos para eliminar.")
        return 0
    
    deleted_count = 0
    
    for _, _, video_name, video_path in tqdm(videos, desc="Eliminando videos"):
        try:
            os.remove(video_path)
            deleted_count += 1
        except Exception as e:
            print(f"⚠️ No se pudo eliminar {video_path}: {e}")
    
    return deleted_count

def delete_videos_by_expression(videos, target_expression):
    """
    Elimina los videos de una expresión específica
    
    Args:
        videos: Lista de tuplas (expresión, muestra, nombre_video, ruta_completa)
        target_expression: Nombre de la expresión cuyos videos se quieren eliminar
    
    Returns:
        int: Número de videos eliminados
    """
    if not videos:
        print("❌ No hay videos para eliminar.")
        return 0
    
    # Filtrar videos por expresión
    videos_to_delete = [v for v in videos if v[0].lower() == target_expression.lower()]
    
    if not videos_to_delete:
        print(f"❌ No se encontraron videos para la expresión '{target_expression}'.")
        return 0
    
    # Mostrar videos que se van a eliminar
    print(f"Se eliminarán {len(videos_to_delete)} videos de la expresión '{target_expression}':")
    for i, (_, muestra, video, _) in enumerate(videos_to_delete, 1):
        print(f"  {i}. {muestra}/{video}")
    
    # Confirmar eliminación
    confirm = input("\n¿Estás seguro de que deseas eliminar estos videos? (s/n): ")
    if confirm.lower() != 's':
        print("❌ Operación cancelada.")
        return 0
    
    deleted_count = 0
    
    for _, _, video_name, video_path in tqdm(videos_to_delete, desc=f"Eliminando videos de '{target_expression}'"):
        try:
            os.remove(video_path)
            deleted_count += 1
        except Exception as e:
            print(f"⚠️ No se pudo eliminar {video_path}: {e}")
    
    return deleted_count

def delete_specific_videos(videos):
    """
    Permite al usuario seleccionar videos específicos para eliminar
    
    Args:
        videos: Lista de tuplas (expresión, muestra, nombre_video, ruta_completa)
    
    Returns:
        int: Número de videos eliminados
    """
    if not videos:
        print("❌ No hay videos para eliminar.")
        return 0
    
    # Mostrar videos numerados
    print("Selecciona los videos que deseas eliminar (ingresa los números separados por comas):\n")
    for i, (expression, muestra, video, _) in enumerate(videos, 1):
        print(f"{i}. {expression}/{muestra}/{video}")
    
    # Solicitar selección
    selection = input("\nNúmeros de videos a eliminar (ej: 1,3,5-7): ")
    
    # Procesar selección
    selected_indices = set()
    
    for part in selection.split(','):
        if '-' in part:
            # Rango (ej: 5-7)
            try:
                start, end = map(int, part.split('-'))
                if 1 <= start <= len(videos) and 1 <= end <= len(videos):
                    selected_indices.update(range(start, end + 1))
            except ValueError:
                print(f"⚠️ Rango inválido: {part}")
        else:
            # Número individual
            try:
                index = int(part)
                if 1 <= index <= len(videos):
                    selected_indices.add(index)
            except ValueError:
                print(f"⚠️ Número inválido: {part}")
    
    if not selected_indices:
        print("❌ No se seleccionaron videos válidos para eliminar.")
        return 0
    
    # Convertir a lista y ordenar
    selected_indices = sorted(list(selected_indices))
    
    # Confirmar eliminación
    print(f"\nSe eliminarán {len(selected_indices)} videos:")
    for idx in selected_indices:
        expression, muestra, video, _ = videos[idx - 1]
        print(f"  - {expression}/{muestra}/{video}")
    
    confirm = input("\n¿Estás seguro de que deseas eliminar estos videos? (s/n): ")
    if confirm.lower() != 's':
        print("❌ Operación cancelada.")
        return 0
    
    # Eliminar videos seleccionados
    deleted_count = 0
    
    for idx in selected_indices:
        _, _, video_name, video_path = videos[idx - 1]
        try:
            os.remove(video_path)
            deleted_count += 1
            print(f"✅ Eliminado: {video_path}")
        except Exception as e:
            print(f"⚠️ No se pudo eliminar {video_path}: {e}")
    
    return deleted_count

# Menú principal
if __name__ == "__main__":
    print("🔍 Buscando videos generados...")
    videos = find_generated_videos()
    
    if not videos:
        print("❌ No se encontraron videos generados en la estructura de carpetas.")
        exit()
    
    while True:
        print("\n===== ELIMINADOR DE VIDEOS GENERADOS =====")
        print(f"Videos encontrados: {len(videos)}")
        print("\n¿Qué acción deseas realizar?")
        print("1. Ver la lista de videos")
        print("2. Eliminar todos los videos")
        print("3. Eliminar videos de una expresión específica")
        print("4. Eliminar videos específicos")
        print("5. Salir")
        
        choice = input("\nIngresa tu opción (1-5): ")
        
        if choice == "1":
            display_videos(videos)
        
        elif choice == "2":
            confirm = input(f"¿Estás seguro de que deseas eliminar TODOS ({len(videos)}) los videos? (s/n): ")
            if confirm.lower() == 's':
                deleted = delete_all_videos(videos)
                print(f"\n✅ {deleted} videos fueron eliminados.")
                if deleted > 0:
                    # Actualizar la lista de videos
                    videos = find_generated_videos()
            else:
                print("❌ Operación cancelada.")
        
        elif choice == "3":
            # Mostrar expresiones disponibles
            expressions = sorted(set(v[0] for v in videos))
            print("\nExpresiones disponibles:")
            for i, exp in enumerate(expressions, 1):
                count = sum(1 for v in videos if v[0] == exp)
                print(f"{i}. {exp} ({count} videos)")
            
            exp_choice = input("\nIngresa el nombre de la expresión: ")
            
            deleted = delete_videos_by_expression(videos, exp_choice)
            if deleted > 0:
                print(f"\n✅ {deleted} videos fueron eliminados.")
                # Actualizar la lista de videos
                videos = find_generated_videos()
        
        elif choice == "4":
            deleted = delete_specific_videos(videos)
            if deleted > 0:
                print(f"\n✅ {deleted} videos fueron eliminados.")
                # Actualizar la lista de videos
                videos = find_generated_videos()
        
        elif choice == "5":
            print("👋 ¡Hasta luego!")
            break
        
        else:
            print("❌ Opción inválida. Por favor, intenta de nuevo.")
# Out:
# 🔍 Buscando videos generados...
#
# ===== ELIMINADOR DE VIDEOS GENERADOS =====
# Videos encontrados: 166
#
# ¿Qué acción deseas realizar?
# 1. Ver la lista de videos
# 2. Eliminar todos los videos
# 3. Eliminar videos de una expresión específica
# 4. Eliminar videos específicos
# 5. Salir
# 📊 Videos encontrados (166):
#
# 1. A ver/muestra_1/a_ver_muestra_1.mp4
#    - Tamaño: 0.70 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 69
#    - Duración: 2.30 segundos
#
# 2. A ver/muestra_1/video_a_ver_muestra_1.mp4
#    - Tamaño: 0.40 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 69
#    - Duración: 2.30 segundos
#
# 3. A ver/muestra_2/a_ver_muestra_2.mp4
#    - Tamaño: 0.72 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 70
#    - Duración: 2.33 segundos
#
# 4. A ver/muestra_2/video_a_ver_muestra_2.mp4
#    - Tamaño: 0.42 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 70
#    - Duración: 2.33 segundos
#
# 5. A ver/muestra_3/a_ver_muestra_3.mp4
#    - Tamaño: 0.62 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 62
#    - Duración: 2.07 segundos
#
# 6. A ver/muestra_3/video_a_ver_muestra_3.mp4
#    - Tamaño: 0.36 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 62
#    - Duración: 2.07 segundos
#
# 7. A ver/muestra_4/a_ver_muestra_4.mp4
#    - Tamaño: 0.72 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 71
#    - Duración: 2.37 segundos
#
# 8. A ver/muestra_4/video_a_ver_muestra_4.mp4
#    - Tamaño: 0.43 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 71
#    - Duración: 2.37 segundos
#
# 9. A ver/muestra_5/a_ver_muestra_5.mp4
#    - Tamaño: 0.83 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 80
#    - Duración: 2.67 segundos
#
# 10. A ver/muestra_5/video_a_ver_muestra_5.mp4
#    - Tamaño: 0.50 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 80
#    - Duración: 2.67 segundos
#
# 11. A ver/muestra_6/a_ver_muestra_6.mp4
#    - Tamaño: 0.69 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 72
#    - Duración: 2.40 segundos
#
# 12. A ver/muestra_6/video_a_ver_muestra_6.mp4
#    - Tamaño: 0.42 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 72
#    - Duración: 2.40 segundos
#
# 13. Aburrido/muestra_1/aburrido_muestra_1.mp4
#    - Tamaño: 0.69 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 68
#    - Duración: 2.27 segundos
#
# 14. Aburrido/muestra_1/video_aburrido_muestra_1.mp4
#    - Tamaño: 0.36 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 68
#    - Duración: 2.27 segundos
#
# 15. Aburrido/muestra_2/aburrido_muestra_2.mp4
#    - Tamaño: 0.81 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 87
#    - Duración: 2.90 segundos
#
# 16. Aburrido/muestra_2/video_aburrido_muestra_2.mp4
#    - Tamaño: 0.46 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 87
#    - Duración: 2.90 segundos
#
# 17. Aburrido/muestra_3/aburrido_muestra_3.mp4
#    - Tamaño: 0.76 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 82
#    - Duración: 2.73 segundos
#
# 18. Aburrido/muestra_3/video_aburrido_muestra_3.mp4
#    - Tamaño: 0.42 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 82
#    - Duración: 2.73 segundos
#
# 19. Aburrido/muestra_4/aburrido_muestra_4.mp4
#    - Tamaño: 0.99 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 106
#    - Duración: 3.53 segundos
#
# 20. Aburrido/muestra_4/video_aburrido_muestra_4.mp4
#    - Tamaño: 0.54 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 106
#    - Duración: 3.53 segundos
#
# 21. Aburrido/muestra_5/aburrido_muestra_5.mp4
#    - Tamaño: 1.27 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 133
#    - Duración: 4.43 segundos
#
# 22. Aburrido/muestra_5/video_aburrido_muestra_5.mp4
#    - Tamaño: 0.67 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 133
#    - Duración: 4.43 segundos
#
# 23. Cansado/muestra_1/cansado_muestra_1.mp4
#    - Tamaño: 0.82 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 86
#    - Duración: 2.87 segundos
#
# 24. Cansado/muestra_1/video_cansado_muestra_1.mp4
#    - Tamaño: 0.45 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 86
#    - Duración: 2.87 segundos
#
# 25. Cansado/muestra_2/cansado_muestra_2.mp4
#    - Tamaño: 0.95 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 102
#    - Duración: 3.40 segundos
#
# 26. Cansado/muestra_2/video_cansado_muestra_2.mp4
#    - Tamaño: 0.52 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 102
#    - Duración: 3.40 segundos
#
# 27. Cansado/muestra_3/cansado_muestra_3.mp4
#    - Tamaño: 0.76 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 75
#    - Duración: 2.50 segundos
#
# 28. Cansado/muestra_3/video_cansado_muestra_3.mp4
#    - Tamaño: 0.41 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 75
#    - Duración: 2.50 segundos
#
# 29. Cansado/muestra_4/cansado_muestra_4.mp4
#    - Tamaño: 0.70 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 75
#    - Duración: 2.50 segundos
#
# 30. Cansado/muestra_4/video_cansado_muestra_4.mp4
#    - Tamaño: 0.39 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 75
#    - Duración: 2.50 segundos
#
# 31. Cansado/muestra_5/cansado_muestra_5.mp4
#    - Tamaño: 0.23 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 19
#    - Duración: 0.63 segundos
#
# 32. Cansado/muestra_5/video_cansado_muestra_5.mp4
#    - Tamaño: 0.13 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 19
#    - Duración: 0.63 segundos
#
# 33. Cansado/muestra_6/cansado_muestra_6.mp4
#    - Tamaño: 0.96 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 94
#    - Duración: 3.13 segundos
#
# 34. Cansado/muestra_6/video_cansado_muestra_6.mp4
#    - Tamaño: 0.50 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 94
#    - Duración: 3.13 segundos
#
# 35. Disgusto/muestra_1/disgusto_muestra_1.mp4
#    - Tamaño: 0.61 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 65
#    - Duración: 2.17 segundos
#
# 36. Disgusto/muestra_1/video_disgusto_muestra_1.mp4
#    - Tamaño: 0.34 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 65
#    - Duración: 2.17 segundos
#
# 37. Disgusto/muestra_2/disgusto_muestra_2.mp4
#    - Tamaño: 0.75 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 73
#    - Duración: 2.43 segundos
#
# 38. Disgusto/muestra_2/video_disgusto_muestra_2.mp4
#    - Tamaño: 0.42 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 73
#    - Duración: 2.43 segundos
#
# 39. Disgusto/muestra_3/disgusto_muestra_3.mp4
#    - Tamaño: 0.66 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 69
#    - Duración: 2.30 segundos
#
# 40. Disgusto/muestra_3/video_disgusto_muestra_3.mp4
#    - Tamaño: 0.38 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 69
#    - Duración: 2.30 segundos
#
# 41. Disgusto/muestra_4/disgusto_muestra_4.mp4
#    - Tamaño: 0.74 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 72
#    - Duración: 2.40 segundos
#
# 42. Disgusto/muestra_4/video_disgusto_muestra_4.mp4
#    - Tamaño: 0.40 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 72
#    - Duración: 2.40 segundos
#
# 43. Disgusto/muestra_5/disgusto_muestra_5.mp4
#    - Tamaño: 0.85 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 86
#    - Duración: 2.87 segundos
#
# 44. Disgusto/muestra_5/video_disgusto_muestra_5.mp4
#    - Tamaño: 0.48 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 86
#    - Duración: 2.87 segundos
#
# 45. Disgusto/muestra_6/disgusto_muestra_6.mp4
#    - Tamaño: 1.03 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 104
#    - Duración: 3.47 segundos
#
# 46. Disgusto/muestra_6/video_disgusto_muestra_6.mp4
#    - Tamaño: 0.54 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 104
#    - Duración: 3.47 segundos
#
# 47. Feliz/muestra_1/feliz_muestra_1.mp4
#    - Tamaño: 0.53 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 55
#    - Duración: 1.83 segundos
#
# 48. Feliz/muestra_1/video_feliz_muestra_1.mp4
#    - Tamaño: 0.30 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 55
#    - Duración: 1.83 segundos
#
# 49. Feliz/muestra_2/feliz_muestra_2.mp4
#    - Tamaño: 1.15 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 111
#    - Duración: 3.70 segundos
#
# 50. Feliz/muestra_2/video_feliz_muestra_2.mp4
#    - Tamaño: 0.63 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 111
#    - Duración: 3.70 segundos
#
# 51. Feliz/muestra_3/feliz_muestra_3.mp4
#    - Tamaño: 1.02 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 112
#    - Duración: 3.73 segundos
#
# 52. Feliz/muestra_3/video_feliz_muestra_3.mp4
#    - Tamaño: 0.60 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 112
#    - Duración: 3.73 segundos
#
# 53. Feliz/muestra_4/feliz_muestra_4.mp4
#    - Tamaño: 0.64 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 63
#    - Duración: 2.10 segundos
#
# 54. Feliz/muestra_4/video_feliz_muestra_4.mp4
#    - Tamaño: 0.38 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 63
#    - Duración: 2.10 segundos
#
# 55. Feliz/muestra_5/feliz_muestra_5.mp4
#    - Tamaño: 0.80 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 81
#    - Duración: 2.70 segundos
#
# 56. Feliz/muestra_5/video_feliz_muestra_5.mp4
#    - Tamaño: 0.46 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 81
#    - Duración: 2.70 segundos
#
# 57. Feliz/muestra_6/feliz_muestra_6.mp4
#    - Tamaño: 1.07 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 100
#    - Duración: 3.33 segundos
#
# 58. Feliz/muestra_6/video_feliz_muestra_6.mp4
#    - Tamaño: 0.60 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 100
#    - Duración: 3.33 segundos
#
# 59. Huele mal/muestra_1/huele_mal_muestra_1.mp4
#    - Tamaño: 1.21 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 110
#    - Duración: 3.67 segundos
#
# 60. Huele mal/muestra_1/video_huele_mal_muestra_1.mp4
#    - Tamaño: 0.66 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 110
#    - Duración: 3.67 segundos
#
# 61. Huele mal/muestra_2/huele_mal_muestra_2.mp4
#    - Tamaño: 0.94 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 90
#    - Duración: 3.00 segundos
#
# 62. Huele mal/muestra_2/video_huele_mal_muestra_2.mp4
#    - Tamaño: 0.51 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 90
#    - Duración: 3.00 segundos
#
# 63. Huele mal/muestra_3/huele_mal_muestra_3.mp4
#    - Tamaño: 1.10 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 99
#    - Duración: 3.30 segundos
#
# 64. Huele mal/muestra_3/video_huele_mal_muestra_3.mp4
#    - Tamaño: 0.58 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 99
#    - Duración: 3.30 segundos
#
# 65. Huele mal/muestra_4/huele_mal_muestra_4.mp4
#    - Tamaño: 1.11 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 98
#    - Duración: 3.27 segundos
#
# 66. Huele mal/muestra_4/video_huele_mal_muestra_4.mp4
#    - Tamaño: 0.57 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 98
#    - Duración: 3.27 segundos
#
# 67. Huele mal/muestra_5/huele_mal_muestra_5.mp4
#    - Tamaño: 1.34 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 119
#    - Duración: 3.97 segundos
#
# 68. Huele mal/muestra_5/video_huele_mal_muestra_5.mp4
#    - Tamaño: 0.70 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 119
#    - Duración: 3.97 segundos
#
# 69. Huele mal/muestra_6/huele_mal_muestra_6.mp4
#    - Tamaño: 1.53 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 134
#    - Duración: 4.47 segundos
#
# 70. Huele mal/muestra_6/video_huele_mal_muestra_6.mp4
#    - Tamaño: 0.79 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 134
#    - Duración: 4.47 segundos
#
# 71. Ladron/muestra_1/ladron_muestra_1.mp4
#    - Tamaño: 0.38 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 47
#    - Duración: 1.57 segundos
#
# 72. Ladron/muestra_1/video_ladron_muestra_1.mp4
#    - Tamaño: 0.26 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 47
#    - Duración: 1.57 segundos
#
# 73. Ladron/muestra_2/ladron_muestra_2.mp4
#    - Tamaño: 0.86 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 88
#    - Duración: 2.93 segundos
#
# 74. Ladron/muestra_2/video_ladron_muestra_2.mp4
#    - Tamaño: 0.48 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 88
#    - Duración: 2.93 segundos
#
# 75. Ladron/muestra_3/ladron_muestra_3.mp4
#    - Tamaño: 0.80 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 84
#    - Duración: 2.80 segundos
#
# 76. Ladron/muestra_3/video_ladron_muestra_3.mp4
#    - Tamaño: 0.43 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 84
#    - Duración: 2.80 segundos
#
# 77. Ladron/muestra_4/ladron_muestra_4.mp4
#    - Tamaño: 0.97 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 92
#    - Duración: 3.07 segundos
#
# 78. Ladron/muestra_4/video_ladron_muestra_4.mp4
#    - Tamaño: 0.50 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 92
#    - Duración: 3.07 segundos
#
# 79. Ladron/muestra_5/ladron_muestra_5.mp4
#    - Tamaño: 0.66 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 65
#    - Duración: 2.17 segundos
#
# 80. Ladron/muestra_5/video_ladron_muestra_5.mp4
#    - Tamaño: 0.38 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 65
#    - Duración: 2.17 segundos
#
# 81. Ladron/muestra_6/ladron_muestra_6.mp4
#    - Tamaño: 0.86 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 90
#    - Duración: 3.00 segundos
#
# 82. Ladron/muestra_6/video_ladron_muestra_6.mp4
#    - Tamaño: 0.45 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 90
#    - Duración: 3.00 segundos
#
# 83. Llorar/muestra_1/llorar_muestra_1.mp4
#    - Tamaño: 0.51 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 58
#    - Duración: 1.93 segundos
#
# 84. Llorar/muestra_1/video_llorar_muestra_1.mp4
#    - Tamaño: 0.31 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 58
#    - Duración: 1.93 segundos
#
# 85. Llorar/muestra_2/llorar_muestra_2.mp4
#    - Tamaño: 0.82 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 81
#    - Duración: 2.70 segundos
#
# 86. Llorar/muestra_2/video_llorar_muestra_2.mp4
#    - Tamaño: 0.42 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 81
#    - Duración: 2.70 segundos
#
# 87. Llorar/muestra_3/llorar_muestra_3.mp4
#    - Tamaño: 0.84 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 94
#    - Duración: 3.13 segundos
#
# 88. Llorar/muestra_3/video_llorar_muestra_3.mp4
#    - Tamaño: 0.48 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 94
#    - Duración: 3.13 segundos
#
# 89. Llorar/muestra_4/llorar_muestra_4.mp4
#    - Tamaño: 1.07 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 115
#    - Duración: 3.83 segundos
#
# 90. Llorar/muestra_4/video_llorar_muestra_4.mp4
#    - Tamaño: 0.56 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 115
#    - Duración: 3.83 segundos
#
# 91. Llorar/muestra_5/llorar_muestra_5.mp4
#    - Tamaño: 1.48 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 152
#    - Duración: 5.07 segundos
#
# 92. Llorar/muestra_5/video_llorar_muestra_5.mp4
#    - Tamaño: 0.79 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 152
#    - Duración: 5.07 segundos
#
# 93. Llorar/muestra_6/llorar_muestra_6.mp4
#    - Tamaño: 1.18 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 125
#    - Duración: 4.17 segundos
#
# 94. Llorar/muestra_6/video_llorar_muestra_6.mp4
#    - Tamaño: 0.64 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 125
#    - Duración: 4.17 segundos
#
# 95. Molesto/muestra_1/molesto_muestra_1.mp4
#    - Tamaño: 0.51 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 54
#    - Duración: 1.80 segundos
#
# 96. Molesto/muestra_1/video_molesto_muestra_1.mp4
#    - Tamaño: 0.32 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 54
#    - Duración: 1.80 segundos
#
# 97. Molesto/muestra_2/molesto_muestra_2.mp4
#    - Tamaño: 0.85 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 86
#    - Duración: 2.87 segundos
#
# 98. Molesto/muestra_2/video_molesto_muestra_2.mp4
#    - Tamaño: 0.44 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 86
#    - Duración: 2.87 segundos
#
# 99. Molesto/muestra_3/molesto_muestra_3.mp4
#    - Tamaño: 0.90 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 91
#    - Duración: 3.03 segundos
#
# 100. Molesto/muestra_3/video_molesto_muestra_3.mp4
#    - Tamaño: 0.48 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 91
#    - Duración: 3.03 segundos
#
# 101. Molesto/muestra_4/molesto_muestra_4.mp4
#    - Tamaño: 0.88 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 85
#    - Duración: 2.83 segundos
#
# 102. Molesto/muestra_4/video_molesto_muestra_4.mp4
#    - Tamaño: 0.46 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 85
#    - Duración: 2.83 segundos
#
# 103. Molesto/muestra_5/molesto_muestra_5.mp4
#    - Tamaño: 0.83 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 88
#    - Duración: 2.93 segundos
#
# 104. Molesto/muestra_5/video_molesto_muestra_5.mp4
#    - Tamaño: 0.45 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 88
#    - Duración: 2.93 segundos
#
# 105. Molesto/muestra_6/molesto_muestra_6.mp4
#    - Tamaño: 1.09 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 108
#    - Duración: 3.60 segundos
#
# 106. Molesto/muestra_6/video_molesto_muestra_6.mp4
#    - Tamaño: 0.54 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 108
#    - Duración: 3.60 segundos
#
# 107. No/muestra_1/no_muestra_1.mp4
#    - Tamaño: 1.24 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 108
#    - Duración: 3.60 segundos
#
# 108. No/muestra_1/video_no_muestra_1.mp4
#    - Tamaño: 0.70 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 108
#    - Duración: 3.60 segundos
#
# 109. No/muestra_2/no_muestra_2.mp4
#    - Tamaño: 0.92 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 79
#    - Duración: 2.63 segundos
#
# 110. No/muestra_2/video_no_muestra_2.mp4
#    - Tamaño: 0.54 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 79
#    - Duración: 2.63 segundos
#
# 111. No/muestra_3/no_muestra_3.mp4
#    - Tamaño: 0.87 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 74
#    - Duración: 2.47 segundos
#
# 112. No/muestra_3/video_no_muestra_3.mp4
#    - Tamaño: 0.49 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 74
#    - Duración: 2.47 segundos
#
# 113. No/muestra_4/no_muestra_4.mp4
#    - Tamaño: 0.81 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 68
#    - Duración: 2.27 segundos
#
# 114. No/muestra_4/video_no_muestra_4.mp4
#    - Tamaño: 0.44 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 68
#    - Duración: 2.27 segundos
#
# 115. No/muestra_5/no_muestra_5.mp4
#    - Tamaño: 0.89 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 75
#    - Duración: 2.50 segundos
#
# 116. No/muestra_5/video_no_muestra_5.mp4
#    - Tamaño: 0.49 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 75
#    - Duración: 2.50 segundos
#
# 117. No/muestra_6/no_muestra_6.mp4
#    - Tamaño: 0.88 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 74
#    - Duración: 2.47 segundos
#
# 118. No/muestra_6/video_no_muestra_6.mp4
#    - Tamaño: 0.46 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 74
#    - Duración: 2.47 segundos
#
# 119. No se/muestra_1/no_se_muestra_1.mp4
#    - Tamaño: 0.56 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 63
#    - Duración: 2.10 segundos
#
# 120. No se/muestra_1/video_no_se_muestra_1.mp4
#    - Tamaño: 0.33 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 63
#    - Duración: 2.10 segundos
#
# 121. No se/muestra_2/no_se_muestra_2.mp4
#    - Tamaño: 0.71 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 78
#    - Duración: 2.60 segundos
#
# 122. No se/muestra_2/video_no_se_muestra_2.mp4
#    - Tamaño: 0.42 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 78
#    - Duración: 2.60 segundos
#
# 123. No se/muestra_3/no_se_muestra_3.mp4
#    - Tamaño: 0.79 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 83
#    - Duración: 2.77 segundos
#
# 124. No se/muestra_3/video_no_se_muestra_3.mp4
#    - Tamaño: 0.43 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 83
#    - Duración: 2.77 segundos
#
# 125. No se/muestra_4/no_se_muestra_4.mp4
#    - Tamaño: 0.95 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 95
#    - Duración: 3.17 segundos
#
# 126. No se/muestra_4/video_no_se_muestra_4.mp4
#    - Tamaño: 0.55 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 95
#    - Duración: 3.17 segundos
#
# 127. No se/muestra_5/no_se_muestra_5.mp4
#    - Tamaño: 0.81 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 75
#    - Duración: 2.50 segundos
#
# 128. No se/muestra_5/video_no_se_muestra_5.mp4
#    - Tamaño: 0.45 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 75
#    - Duración: 2.50 segundos
#
# 129. No se/muestra_6/no_se_muestra_6.mp4
#    - Tamaño: 1.03 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 104
#    - Duración: 3.47 segundos
#
# 130. No se/muestra_6/video_no_se_muestra_6.mp4
#    - Tamaño: 0.55 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 104
#    - Duración: 3.47 segundos
#
# 131. Si/muestra_1/si_muestra_1.mp4
#    - Tamaño: 0.77 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 80
#    - Duración: 2.67 segundos
#
# 132. Si/muestra_1/video_si_muestra_1.mp4
#    - Tamaño: 0.46 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 80
#    - Duración: 2.67 segundos
#
# 133. Si/muestra_2/si_muestra_2.mp4
#    - Tamaño: 0.81 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 82
#    - Duración: 2.73 segundos
#
# 134. Si/muestra_2/video_si_muestra_2.mp4
#    - Tamaño: 0.46 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 82
#    - Duración: 2.73 segundos
#
# 135. Si/muestra_3/si_muestra_3.mp4
#    - Tamaño: 0.86 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 85
#    - Duración: 2.83 segundos
#
# 136. Si/muestra_3/video_si_muestra_3.mp4
#    - Tamaño: 0.48 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 85
#    - Duración: 2.83 segundos
#
# 137. Si/muestra_4/si_muestra_4.mp4
#    - Tamaño: 0.69 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 69
#    - Duración: 2.30 segundos
#
# 138. Si/muestra_4/video_si_muestra_4.mp4
#    - Tamaño: 0.37 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 69
#    - Duración: 2.30 segundos
#
# 139. Si/muestra_5/si_muestra_5.mp4
#    - Tamaño: 0.86 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 83
#    - Duración: 2.77 segundos
#
# 140. Si/muestra_5/video_si_muestra_5.mp4
#    - Tamaño: 0.47 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 83
#    - Duración: 2.77 segundos
#
# 141. Si/muestra_6/si_muestra_6.mp4
#    - Tamaño: 0.96 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 97
#    - Duración: 3.23 segundos
#
# 142. Si/muestra_6/video_si_muestra_6.mp4
#    - Tamaño: 0.50 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 97
#    - Duración: 3.23 segundos
#
# 143. Sorpresa/muestra_1/sorpresa_muestra_1.mp4
#    - Tamaño: 0.55 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 57
#    - Duración: 1.90 segundos
#
# 144. Sorpresa/muestra_1/video_sorpresa_muestra_1.mp4
#    - Tamaño: 0.31 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 57
#    - Duración: 1.90 segundos
#
# 145. Sorpresa/muestra_2/sorpresa_muestra_2.mp4
#    - Tamaño: 0.73 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 75
#    - Duración: 2.50 segundos
#
# 146. Sorpresa/muestra_2/video_sorpresa_muestra_2.mp4
#    - Tamaño: 0.43 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 75
#    - Duración: 2.50 segundos
#
# 147. Sorpresa/muestra_3/sorpresa_muestra_3.mp4
#    - Tamaño: 0.92 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 91
#    - Duración: 3.03 segundos
#
# 148. Sorpresa/muestra_3/video_sorpresa_muestra_3.mp4
#    - Tamaño: 0.52 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 91
#    - Duración: 3.03 segundos
#
# 149. Sorpresa/muestra_4/sorpresa_muestra_4.mp4
#    - Tamaño: 0.82 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 83
#    - Duración: 2.77 segundos
#
# 150. Sorpresa/muestra_4/video_sorpresa_muestra_4.mp4
#    - Tamaño: 0.44 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 83
#    - Duración: 2.77 segundos
#
# 151. Sorpresa/muestra_5/sorpresa_muestra_5.mp4
#    - Tamaño: 0.29 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 25
#    - Duración: 0.83 segundos
#
# 152. Sorpresa/muestra_5/video_sorpresa_muestra_5.mp4
#    - Tamaño: 0.16 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 25
#    - Duración: 0.83 segundos
#
# 153. Sorpresa/muestra_6/sorpresa_muestra_6.mp4
#    - Tamaño: 0.99 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 94
#    - Duración: 3.13 segundos
#
# 154. Sorpresa/muestra_6/video_sorpresa_muestra_6.mp4
#    - Tamaño: 0.52 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 94
#    - Duración: 3.13 segundos
#
# 155. Triste/muestra_1/triste_muestra_1.mp4
#    - Tamaño: 0.95 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 110
#    - Duración: 3.67 segundos
#
# 156. Triste/muestra_1/video_triste_muestra_1.mp4
#    - Tamaño: 0.56 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 110
#    - Duración: 3.67 segundos
#
# 157. Triste/muestra_2/triste_muestra_2.mp4
#    - Tamaño: 0.80 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 89
#    - Duración: 2.97 segundos
#
# 158. Triste/muestra_2/video_triste_muestra_2.mp4
#    - Tamaño: 0.45 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 89
#    - Duración: 2.97 segundos
#
# 159. Triste/muestra_3/triste_muestra_3.mp4
#    - Tamaño: 1.01 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 106
#    - Duración: 3.53 segundos
#
# 160. Triste/muestra_3/video_triste_muestra_3.mp4
#    - Tamaño: 0.57 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 106
#    - Duración: 3.53 segundos
#
# 161. Triste/muestra_4/triste_muestra_4.mp4
#    - Tamaño: 1.01 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 106
#    - Duración: 3.53 segundos
#
# 162. Triste/muestra_4/video_triste_muestra_4.mp4
#    - Tamaño: 0.53 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 106
#    - Duración: 3.53 segundos
#
# 163. Triste/muestra_5/triste_muestra_5.mp4
#    - Tamaño: 0.64 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 69
#    - Duración: 2.30 segundos
#
# 164. Triste/muestra_5/video_triste_muestra_5.mp4
#    - Tamaño: 0.34 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 69
#    - Duración: 2.30 segundos
#
# 165. Triste/muestra_6/triste_muestra_6.mp4
#    - Tamaño: 0.82 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 84
#    - Duración: 2.80 segundos
#
# 166. Triste/muestra_6/video_triste_muestra_6.mp4
#    - Tamaño: 0.41 MB
#    - Resolución: 640x640
#    - FPS: 30.00
#    - Frames: 84
#    - Duración: 2.80 segundos
#
#
# ===== ELIMINADOR DE VIDEOS GENERADOS =====
# Videos encontrados: 166
#
# ¿Qué acción deseas realizar?
# 1. Ver la lista de videos
# 2. Eliminar todos los videos
# 3. Eliminar videos de una expresión específica
# 4. Eliminar videos específicos
# 5. Salir
# 👋 ¡Hasta luego!

# %%
import os
import glob
import shutil
import time

def delete_keyframe_folders(base_path):
    """
    Elimina todas las carpetas llamadas "Keyframe" en la estructura de directorios
    
    Args:
        base_path: Ruta base donde buscar las carpetas Keyframe
    
    Returns:
        Dict: Estadísticas de las carpetas eliminadas
    """
    start_time = time.time()
    
    # Estadísticas
    stats = {
        'total_folders_found': 0,
        'folders_deleted': 0,
        'folders_failed': 0,
        'details': []
    }
    
    # Buscar todas las carpetas "Keyframe"
    keyframe_pattern = os.path.join(base_path, "**", "Keyframe")
    keyframe_folders = glob.glob(keyframe_pattern, recursive=True)
    
    stats['total_folders_found'] = len(keyframe_folders)
    
    if not keyframe_folders:
        print(f"❌ No se encontraron carpetas 'Keyframe' en: {base_path}")
        return stats
    
    print(f"🔍 Se encontraron {len(keyframe_folders)} carpetas 'Keyframe'.")
    
    # Pedir confirmación
    confirm = input(f"¿Estás seguro de que deseas eliminar {len(keyframe_folders)} carpetas 'Keyframe'? (s/n): ")
    if confirm.lower() != 's':
        print("❌ Operación cancelada.")
        return stats
    
    # Eliminar cada carpeta
    for i, folder_path in enumerate(keyframe_folders, 1):
        try:
            print(f"[{i}/{len(keyframe_folders)}] Eliminando: {folder_path}")
            
            # Contar archivos
            file_count = len([name for name in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, name))])
            
            # Eliminar la carpeta y su contenido
            shutil.rmtree(folder_path)
            
            stats['folders_deleted'] += 1
            stats['details'].append({
                'path': folder_path,
                'files': file_count,
                'success': True,
                'error': None
            })
            
            print(f"✅ Carpeta eliminada ({file_count} archivos)")
            
        except Exception as e:
            print(f"❌ Error al eliminar {folder_path}: {str(e)}")
            stats['folders_failed'] += 1
            stats['details'].append({
                'path': folder_path,
                'success': False,
                'error': str(e)
            })
    
    # Mostrar resumen
    total_time = time.time() - start_time
    print("\n==== RESUMEN DE ELIMINACIÓN ====")
    print(f"Total de carpetas encontradas: {stats['total_folders_found']}")
    print(f"Carpetas eliminadas con éxito: {stats['folders_deleted']}")
    print(f"Carpetas con errores: {stats['folders_failed']}")
    print(f"Tiempo total: {total_time:.2f} segundos")
    
    return stats

def main():
    """
    Función principal para eliminar carpetas Keyframe
    """
    # Configurar ruta base donde están los datos procesados
    base_path = r'C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data'
    
    print("🚀 Iniciando búsqueda de carpetas 'Keyframe' para eliminar...")
    
    # Opción para mostrar ejemplos de carpetas antes de proceder
    show_examples = input("¿Deseas ver ejemplos de las carpetas que se encontrarán? (s/n): ")
    if show_examples.lower() == 's':
        keyframe_pattern = os.path.join(base_path, "**", "Keyframe")
        keyframe_folders = glob.glob(keyframe_pattern, recursive=True)
        
        if keyframe_folders:
            print("\nEjemplos de carpetas que serán eliminadas:")
            for i, folder in enumerate(keyframe_folders[:5], 1):
                print(f"  {i}. {folder}")
            
            if len(keyframe_folders) > 5:
                print(f"  ... y {len(keyframe_folders) - 5} carpetas más.")
        else:
            print("No se encontraron carpetas 'Keyframe'.")
    
    # Preguntar si quiere continuar
    proceed = input("\n¿Deseas continuar con la eliminación? (s/n): ")
    if proceed.lower() != 's':
        print("❌ Operación cancelada.")
        return
    
    # Ejecutar la eliminación
    stats = delete_keyframe_folders(base_path)
    
    # Guardar estadísticas en archivo (opcional)
    try:
        import json
        with open(os.path.join(base_path, "eliminacion_keyframe_stats.json"), "w") as f:
            json.dump(stats, f, indent=2)
        print(f"📊 Estadísticas guardadas en {os.path.join(base_path, 'eliminacion_keyframe_stats.json')}")
    except Exception as e:
        print(f"⚠️ No se pudieron guardar las estadísticas: {str(e)}")
    
    print("\n✅ Proceso de eliminación completado.")

# Ejecutar si se llama directamente
if __name__ == "__main__":
    main()
# Out:
# 🚀 Iniciando búsqueda de carpetas 'Keyframe' para eliminar...
#
# Ejemplos de carpetas que serán eliminadas:
#   1. C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO 3\señas_procesadas\A ver\muestra_1\Keyframe
#   2. C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO 3\señas_procesadas\A ver\muestra_2\Keyframe
#   3. C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO 3\señas_procesadas\A ver\muestra_3\Keyframe
#   4. C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO 3\señas_procesadas\A ver\muestra_4\Keyframe
#   5. C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO 3\señas_procesadas\Aburrido\muestra_1\Keyframe
#   ... y 71 carpetas más.
# 🔍 Se encontraron 76 carpetas 'Keyframe'.
# [1/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO 3\señas_procesadas\A ver\muestra_1\Keyframe
# ✅ Carpeta eliminada (1 archivos)
# [2/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO 3\señas_procesadas\A ver\muestra_2\Keyframe
# ✅ Carpeta eliminada (1 archivos)
# [3/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO 3\señas_procesadas\A ver\muestra_3\Keyframe
# ✅ Carpeta eliminada (1 archivos)
# [4/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO 3\señas_procesadas\A ver\muestra_4\Keyframe
# ✅ Carpeta eliminada (1 archivos)
# [5/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO 3\señas_procesadas\Aburrido\muestra_1\Keyframe
# ✅ Carpeta eliminada (1 archivos)
# [6/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO 3\señas_procesadas\Aburrido\muestra_2\Keyframe
# ✅ Carpeta eliminada (1 archivos)
# [7/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO 3\señas_procesadas\Aburrido\muestra_3\Keyframe
# ✅ Carpeta eliminada (1 archivos)
# [8/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO 3\señas_procesadas\Aburrido\muestra_4\Keyframe
# ✅ Carpeta eliminada (1 archivos)
# [9/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO 3\señas_procesadas\Aburrido\muestra_5\Keyframe
# ✅ Carpeta eliminada (1 archivos)
# [10/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO 3\señas_procesadas\Cansado\muestra_1\Keyframe
# ✅ Carpeta eliminada (1 archivos)
# [11/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO 3\señas_procesadas\Cansado\muestra_2\Keyframe
# ✅ Carpeta eliminada (1 archivos)
# [12/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO 3\señas_procesadas\Cansado\muestra_3\Keyframe
# ✅ Carpeta eliminada (1 archivos)
# [13/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO 3\señas_procesadas\Cansado\muestra_4\Keyframe
# ✅ Carpeta eliminada (1 archivos)
# [14/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO 3\señas_procesadas\Cansado\muestra_5\Keyframe
# ✅ Carpeta eliminada (1 archivos)
# [15/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO 3\señas_procesadas\Disgusto\muestra_1\Keyframe
# ✅ Carpeta eliminada (1 archivos)
# [16/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO 3\señas_procesadas\Disgusto\muestra_2\Keyframe
# ✅ Carpeta eliminada (1 archivos)
# [17/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO 3\señas_procesadas\Disgusto\muestra_3\Keyframe
# ✅ Carpeta eliminada (1 archivos)
# [18/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO 3\señas_procesadas\Disgusto\muestra_4\Keyframe
# ✅ Carpeta eliminada (1 archivos)
# [19/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO 3\señas_procesadas\Feliz\muestra_1\Keyframe
# ✅ Carpeta eliminada (1 archivos)
# [20/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO 3\señas_procesadas\Feliz\muestra_2\Keyframe
# ✅ Carpeta eliminada (1 archivos)
# [21/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO 3\señas_procesadas\Feliz\muestra_3\Keyframe
# ✅ Carpeta eliminada (1 archivos)
# [22/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO 3\señas_procesadas\Feliz\muestra_4\Keyframe
# ✅ Carpeta eliminada (1 archivos)
# [23/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO 3\señas_procesadas\Feliz\muestra_5\Keyframe
# ✅ Carpeta eliminada (1 archivos)
# [24/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO 3\señas_procesadas\Huele mal\muestra_1\Keyframe
# ✅ Carpeta eliminada (1 archivos)
# [25/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO 3\señas_procesadas\Huele mal\muestra_2\Keyframe
# ✅ Carpeta eliminada (1 archivos)
# [26/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO 3\señas_procesadas\Huele mal\muestra_3\Keyframe
# ✅ Carpeta eliminada (1 archivos)
# [27/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO 3\señas_procesadas\Ladron\muestra_1\Keyframe
# ✅ Carpeta eliminada (1 archivos)
# [28/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO 3\señas_procesadas\Ladron\muestra_2\Keyframe
# ✅ Carpeta eliminada (1 archivos)
# [29/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO 3\señas_procesadas\Ladron\muestra_3\Keyframe
# ✅ Carpeta eliminada (1 archivos)
# [30/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO 3\señas_procesadas\Ladron\muestra_4\Keyframe
# ✅ Carpeta eliminada (1 archivos)
# [31/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO 3\señas_procesadas\Ladron\muestra_5\Keyframe
# ✅ Carpeta eliminada (1 archivos)
# [32/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO 3\señas_procesadas\Llorar\muestra_1\Keyframe
# ✅ Carpeta eliminada (1 archivos)
# [33/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO 3\señas_procesadas\Llorar\muestra_2\Keyframe
# ✅ Carpeta eliminada (1 archivos)
# [34/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO 3\señas_procesadas\Llorar\muestra_3\Keyframe
# ✅ Carpeta eliminada (1 archivos)
# [35/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO 3\señas_procesadas\Llorar\muestra_4\Keyframe
# ✅ Carpeta eliminada (1 archivos)
# [36/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO 3\señas_procesadas\Llorar\muestra_5\Keyframe
# ✅ Carpeta eliminada (1 archivos)
# [37/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO 3\señas_procesadas\Molesto\muestra_1\Keyframe
# ✅ Carpeta eliminada (1 archivos)
# [38/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO 3\señas_procesadas\Molesto\muestra_2\Keyframe
# ✅ Carpeta eliminada (1 archivos)
# [39/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO 3\señas_procesadas\Molesto\muestra_3\Keyframe
# ✅ Carpeta eliminada (1 archivos)
# [40/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO 3\señas_procesadas\Molesto\muestra_4\Keyframe
# ✅ Carpeta eliminada (1 archivos)
# [41/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO 3\señas_procesadas\Molesto\muestra_5\Keyframe
# ✅ Carpeta eliminada (1 archivos)
# [42/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO 3\señas_procesadas\No\muestra_1\Keyframe
# ✅ Carpeta eliminada (1 archivos)
# [43/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO 3\señas_procesadas\No\muestra_2\Keyframe
# ✅ Carpeta eliminada (1 archivos)
# [44/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO 3\señas_procesadas\No\muestra_3\Keyframe
# ✅ Carpeta eliminada (1 archivos)
# [45/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO 3\señas_procesadas\No\muestra_4\Keyframe
# ✅ Carpeta eliminada (1 archivos)
# [46/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO 3\señas_procesadas\No se\muestra_1\Keyframe
# ✅ Carpeta eliminada (1 archivos)
# [47/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO 3\señas_procesadas\No se\muestra_2\Keyframe
# ✅ Carpeta eliminada (1 archivos)
# [48/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO 3\señas_procesadas\No se\muestra_3\Keyframe
# ✅ Carpeta eliminada (1 archivos)
# [49/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO 3\señas_procesadas\No se\muestra_4\Keyframe
# ✅ Carpeta eliminada (1 archivos)
# [50/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO 3\señas_procesadas\Si\muestra_1\Keyframe
# ✅ Carpeta eliminada (1 archivos)
# [51/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO 3\señas_procesadas\Si\muestra_2\Keyframe
# ✅ Carpeta eliminada (1 archivos)
# [52/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO 3\señas_procesadas\Si\muestra_3\Keyframe
# ✅ Carpeta eliminada (1 archivos)
# [53/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO 3\señas_procesadas\Si\muestra_4\Keyframe
# ✅ Carpeta eliminada (1 archivos)
# [54/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO 3\señas_procesadas\Sorpresa\muestra_1\Keyframe
# ✅ Carpeta eliminada (1 archivos)
# [55/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO 3\señas_procesadas\Sorpresa\muestra_2\Keyframe
# ✅ Carpeta eliminada (1 archivos)
# [56/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO 3\señas_procesadas\Sorpresa\muestra_3\Keyframe
# ✅ Carpeta eliminada (1 archivos)
# [57/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO 3\señas_procesadas\Sorpresa\muestra_4\Keyframe
# ✅ Carpeta eliminada (1 archivos)
# [58/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO 3\señas_procesadas\Sorpresa\muestra_5\Keyframe
# ✅ Carpeta eliminada (1 archivos)
# [59/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO 3\señas_procesadas\Triste\muestra_1\Keyframe
# ✅ Carpeta eliminada (1 archivos)
# [60/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO 3\señas_procesadas\Triste\muestra_2\Keyframe
# ✅ Carpeta eliminada (1 archivos)
# [61/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO 3\señas_procesadas\Triste\muestra_3\Keyframe
# ✅ Carpeta eliminada (1 archivos)
# [62/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO 3\señas_procesadas\Triste\muestra_4\Keyframe
# ✅ Carpeta eliminada (1 archivos)
# [63/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO 3\señas_procesadas\Triste\muestra_5\Keyframe
# ✅ Carpeta eliminada (0 archivos)
# [64/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO_2\senas_procesadas\Sorpresa\muestra_4\Keyframe
# ✅ Carpeta eliminada (32 archivos)
# [65/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO_4\senas_procesadas\A ver\muestra_1\Keyframe
# ✅ Carpeta eliminada (37 archivos)
# [66/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO_4\senas_procesadas\A ver\muestra_2\Keyframe
# ✅ Carpeta eliminada (23 archivos)
# [67/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO_4\senas_procesadas\A ver\muestra_3\Keyframe
# ✅ Carpeta eliminada (0 archivos)
# [68/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO_4\senas_procesadas\A ver\muestra_4\Keyframe
# ✅ Carpeta eliminada (4 archivos)
# [69/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO_4\senas_procesadas\A ver\muestra_5\Keyframe
# ✅ Carpeta eliminada (7 archivos)
# [70/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO_4\senas_procesadas\Aburrido\muestra_1\Keyframe
# ✅ Carpeta eliminada (10 archivos)
# [71/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO_4\senas_procesadas\Aburrido\muestra_2\Keyframe
# ✅ Carpeta eliminada (0 archivos)
# [72/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO_4\senas_procesadas\Aburrido\muestra_3\Keyframe
# ✅ Carpeta eliminada (15 archivos)
# [73/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO_4\senas_procesadas\Aburrido\muestra_4\Keyframe
# ✅ Carpeta eliminada (7 archivos)
# [74/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO_4\senas_procesadas\Aburrido\muestra_5\Keyframe
# ✅ Carpeta eliminada (12 archivos)
# [75/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO_4\senas_procesadas\Cansado\muestra_1\Keyframe
# ✅ Carpeta eliminada (47 archivos)
# [76/76] Eliminando: C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\SUJETO_4\senas_procesadas\Cansado\muestra_2\Keyframe
# ✅ Carpeta eliminada (22 archivos)
#
# ==== RESUMEN DE ELIMINACIÓN ====
# Total de carpetas encontradas: 76
# Carpetas eliminadas con éxito: 76
# Carpetas con errores: 0
# Tiempo total: 19.64 segundos
# 📊 Estadísticas guardadas en C:\Users\Invitado\Documents\facial_expression_detector\data_procesada\data\eliminacion_keyframe_stats.json
#
# ✅ Proceso de eliminación completado.
